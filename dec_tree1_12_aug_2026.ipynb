# %%
import numpy as np
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ![image.png](attachment:0d4308bb-3087-4e76-b438-4eb7f46ed0dd.png)

# %% [markdown]
# ![image.png](attachment:18ed5372-4b08-4445-9b9a-53af7512cad0.png)

# %% [markdown]
# ![image.png](attachment:ded00a82-5a24-4704-b151-4b53b3de55b9.png)

# %% [markdown]
# ![image.png](attachment:1a282257-cf3d-40c7-a604-6edc41f574a0.png)

# %% [markdown]
# ![image.png](attachment:e17ff08f-7c60-4cab-ba1d-99498804a5c6.png)

# %% [markdown]
# ![image.png](attachment:edc03216-79df-412d-b810-21c5252d4d39.png)

# %% [markdown]
# ![image.png](attachment:aed701d8-262b-479c-8993-ff09f9cf8a69.png)

# %% [markdown]
# ![image.png](attachment:097a5b4e-2175-4de3-9d39-bb909e14328a.png)

# %% [markdown]
# ![image.png](attachment:848667e5-7412-4927-9766-24d0a6814f08.png)

# %% [markdown]
# ![image.png](attachment:fe108cda-1789-4f71-8bae-27f68bfd4995.png)

# %% [markdown]
# ![image.png](attachment:cfc98433-fa25-4a0f-ac2c-a403770cba8c.png)

# %% [markdown]
# ![image.png](attachment:6713b0bd-c321-404c-a0e6-dc4f11bdf475.png)

# %% [markdown]
# ![image.png](attachment:de170420-7830-47db-a57f-6bf509db755d.png)

# %% [markdown]
# ![image.png](attachment:e98ef4ce-b05c-4d5c-8b12-63182effc9fe.png)

# %% [markdown]
# ![image.png](attachment:5b23e91a-8a0d-4325-9250-91cb0841b60f.png)

# %% [markdown]
# ![image.png](attachment:c4acd10d-503e-4968-90dc-84ee835fb4bc.png)

# %% [markdown]
# ![image.png](attachment:0c459c79-e3b6-4a51-898b-6822974b1b8d.png)

# %%
# 1) A: 5  B: 5 = 0.5
# 2) A: 10 B: 0 = 0  1 - [(0/10)**2 + (10/10)**2) = 1 - [0 + 1] = 1 - 1 = 0
# 3) A: 0  B: 10 = 0

# %% [markdown]
# 4
# ![image.png](attachment:bfd9ceb6-95a1-4713-b96f-6e13de30a68e.png)

# %%
# 5) A: 2 B: 2 C: 2        = 1 - [(1/3)**2 + (1/3)**2 + (1/3)**2] = 1 - 1/3 = 2/3
# 6) A: 3 B: 3 C: 3 D: 3   = 1 - [(1/4)**2 + (1/4)**2 + (1/4)**2 + (1/4)**2] = 1 - 1/4 = 3/4

# %% [markdown]
# ![image.png](attachment:c204514c-6253-4d90-a3a5-8085f29bc748.png)

# %% [markdown]
# START
# ![image.png](attachment:bfd9ceb6-95a1-4713-b96f-6e13de30a68e.png)
#
# GI = 0.5
#
# Option 1: x1 > 3
# Option 2: x2 <= 2

# %%
# Option 1 x1 > 3
# Yes:
# A: 1 B: 2
# 1 - [(1/3)**2 + (2/3)**2] = 1 - [1/9 + 4/9] = 1 - 5/9 = 4/9 ~0.44
# No:
# A: 2 B: 1
# 1 - [(2/3)**2 + (1/3)**2] = 1 - [4/9 + 1/9] = 1 - 5/9 = 4/9 ~0.44
# Option 2: x2 <= 2
# Yes: ? No: ? Weighted: ? Gain: ? -- which option was better? 1 or 2?

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import numpy as np

# Data
X = np.array([[1, 3], [2, 1], [3, 2], [4, 3], [5, 1], [6, 2]])

y = np.array(['A', 'A', 'B', 'B', 'A', 'B'])

clf = DecisionTreeClassifier(criterion='gini', random_state=42)
clf.fit(X, y)

y_pred = clf.predict(X)

# Metrics
accuracy = accuracy_score(y, y_pred)
precision = precision_score(y, y_pred, average='macro')
recall = recall_score(y, y_pred, average='macro')
f1 = f1_score(y, y_pred, average='macro')
cm = confusion_matrix(y, y_pred)
report = classification_report(y, y_pred)

print("Accuracy:", accuracy)
print("Precision (macro):", precision)
print("Recall (macro):", recall)
print("F1 Score (macro):", f1)
print("Confusion Matrix:\n", cm)
print("Classification Report:\n", report)
# Out:
# Accuracy: 1.0
# Precision (macro): 1.0
# Recall (macro): 1.0
# F1 Score (macro): 1.0
# Confusion Matrix:
#  [[3 0]
#  [0 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00         3
#            B       1.00      1.00      1.00         3
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.tree import export_text
import numpy as np

# Data
X = np.array([
    [2, 5],
    [4, 3],
    [6, 4],
    [8, 5],
    [10, 3],
    [12, 4]
])

y = np.array(['A', 'A', 'B', 'B', 'A', 'B'])
